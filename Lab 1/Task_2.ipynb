# %% [markdown]
# # 1. Create a new dataframe with only selected columns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# Load the dataset
df = pd.read_csv("/content/drive/MyDrive/Jana/SE4050-DL-Lecture02-main/SE4050-DL-Lecture02-main/Au_nanoparticle_dataset.csv")

# Show the first five rows
df.head()
# Out:
#    ID    T       tau  time  N_total  N_bulk  N_surface        Volume    R_min  \
# 0   1  273  0.000025     1     1599    1014        585  2.710000e-26  15.5898
# 1   2  273  0.000025     2     1642    1034        608  2.780000e-26  15.3996
# 2   3  273  0.000025     3     4637    3365       1272  7.850000e-26  21.9199
# 3   4  273  0.000025     4     7189    5292       1897  1.220000e-25  23.2542
# 4   5  273  0.000025     5    11004    8508       2496  1.860000e-25  27.1200
#
#      R_max  ...  q6q6_S14  q6q6_S15  q6q6_S16  q6q6_S17  q6q6_S18  q6q6_S19  \
# 0  19.4516  ...         0         0         0         0         0         0
# 1  24.1755  ...         0         0         0         0         0         0
# 2  31.0305  ...         0         0         0         0         0         0
# 3  37.8795  ...         0         0         0         0         0         0
# 4  39.7614  ...         0         0         0         0         0         0
#
# ...

# %%
# Filter only the required columns
new_df = df[['N_total', 'N_bulk', 'N_surface', 'R_avg']]

# %% [markdown]
# # 2. Display the first 20 samples

# %%
new_df.head(20)
# Out:
#     N_total  N_bulk  N_surface    R_avg
# 0      1599    1014        585  17.3706
# 1      1642    1034        608  17.6061
# 2      4637    3365       1272  25.3692
# 3      7189    5292       1897  29.7011
# 4     11004    8508       2496  34.2831
# 5     13375   10768       2607  36.6334
# 6     13795   11155       2640  37.0108
# 7     13947   11304       2643  37.1672
# 8     14020   11357       2663  37.2103
# 9     14056   11389       2667  37.2467
# 10     1534     966        568  17.1107
# 11     1559     974        585  17.2101
# 12     4356    3099       1257  24.8253
# 13     6550    4675       1875  29.0376
# 14    10175    7748       2427  33.4399
# 15    12393    9842       2551  35.6950
# 16    13207   10590       2617  36.4657
# 17    13543   10937       2606  36.7871
# 18    13713   11079       2634  36.9333
# 19    13791   11151       2640  37.0104

# %% [markdown]
# # 3. Calculate mean, std, and quartiles

# %%
# Mean
mean_values = new_df.mean()
print("Mean:\n", mean_values)

# Standard Deviation
std_values = new_df.std()
print("\nStandard Deviation:\n", std_values)

# Quartiles
quartiles = new_df.quantile([0.25, 0.5, 0.75])
print("\nQuartiles:\n", quartiles)
# Out:
# Mean:
#  N_total      3476.786500
# N_bulk       2521.550250
# N_surface     955.236250
# R_avg          20.654363
# dtype: float64
#
# Standard Deviation:
#  N_total      3679.286769
# N_bulk       2976.232459
# N_surface     721.870220
# R_avg           7.610716
# dtype: float64
#
# Quartiles:
#        N_total   N_bulk  N_surface      R_avg
# 0.25   1061.0   618.75     437.00  15.160725
# 0.50   1867.0  1199.00     666.00  18.629250
# 0.75   4503.0  3183.00    1301.75  25.525125

# %% [markdown]
# # 4. Plot histograms in a 1x4 layout

# %%
import matplotlib.pyplot as plt

features = ['N_total', 'N_bulk', 'N_surface', 'R_avg']
plt.figure(figsize=(20, 4))

for i, feature in enumerate(features):
    plt.subplot(1, 4, i+1)
    plt.hist(new_df[feature], bins=30, color='skyblue', edgecolor='black')
    plt.title(f'Histogram of {feature}')
    plt.xlabel(feature)
    plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %% [markdown]
# # 5. Visualize scatter plots and histograms using sns.pairplot()

# %%
import seaborn as sns

sns.pairplot(new_df, diag_kind="hist")
plt.suptitle("Pairplot of Selected Features", y=1.02)
plt.show()

# %% [markdown]
# # 6. Customized PairGrid with diagonal hist+KDE, lower KDE, upper histograms

# %%
g = sns.PairGrid(new_df)

# Upper triangle: 2D histogram
g.map_upper(sns.histplot)

# Diagonal: histogram + KDE
g.map_diag(sns.histplot, kde=True)

# Lower triangle: bivariate KDE
g.map_lower(sns.kdeplot, fill=True, cmap="Blues")

plt.suptitle("Customized PairGrid with KDE and Histograms", y=1.02)
plt.show()
